# %% [markdown]
# ### 0. Miscellaneous

# %%
import math
import numpy
import random
import datetime
import os
import json

# %%
print(dir(math))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %%
"{:.4f}".format(math.pi)
# Out:
# '3.1416'

# %%
math.log(32,2)
# Out:
# 5.0

# %%
import math as mt #alias

# %%
mt.pi
# Out:
# 3.141592653589793

# %%
from math import *
from numpy import *
print(pi, log(32,2))
"""
These kinds of "star imports" can occasionally lead to weird, 
difficult-to-debug situations.

The problem in this case is that the math and numpy modules 
both have functions called log, but they have different semantics. 
Because we import from numpy second, its log overwrites (or "shadows") 
the log variable we imported from math
"""
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 from math import *
#       2 from numpy import *
# ----> 3 print(pi, log(32,2))
#       4 """
#       5 These kinds of "star imports" can occasionally lead to weird,
#       6 difficult-to-debug situations.
#    (...)
#      11 the log variable we imported from math
#      12 """
#
# TypeError: return arrays must be of ArrayType

# %%
[3,2,5] + 10

# %%
array([5,3,6,7]) + 10

# %%
alist = [[1,2,3],[5,6,7]]
arr = numpy.asarray(alist)
print("{}\n{}".format(alist,arr))

# %%
arr[1,-1] # arr[row, position]

# %% [markdown]
# ### 1. Builtin modules

# %%
#Math module
print(math.sqrt(144))
print(math.pi)
print(math.log(32,2))
print(math.ceil(4.4))
print(math.floor(4.9))
# Out:
# 12.0
# 3.141592653589793
# 5.0
# 5
# 4

# %%
#random 
random.seed(42)
print(random.random())
print(random.randint(1,100))
random.seed(42)
print(random.random())

data = [1,2,3,4,5,6,7,8,9,0]
random.shuffle(data)
print(data)
sample = random.sample(data, 3)
print(sample)
# Out:
# 0.6394267984578837
# 4
# 0.6394267984578837
# [8, 6, 3, 9, 0, 7, 2, 4, 5, 1]
# [8, 1, 6]
# [8, 6, 3, 9, 0, 7, 2, 4, 5, 1]

# %%
#datetime
now = datetime.datetime.now()
print(now.strftime("%y-%m-%d %H:%M"))
today = datetime.datetime.today()
print(today)
# Out:
# 26-04-21 22:32
# 2026-04-21 22:32:42.045282

# %%
#Operating system
print(os.getcwd())
print(os.listdir("."))
os.makedirs("Miscellaneous",exist_ok=True)
# Out:
# C:\Users\chira\OneDrive\Desktop\AI_DATA_Py\AI_ML_Prep\Daily_Practice
# ['.ipynb_checkpoints', 'day_1.ipynb', 'Day_2.ipynb', 'Day_3.ipynb', 'Day_4.ipynb', 'Day_5.ipynb', 'run_py.txt', 'scores.txt', 'students.csv', 'text.txt', 'text_2.txt', 'text_copy.txt', 'watch.png', 'watch_copy.png']

# %%
#JSON

config = {"model":"RandomForest", "n_estimators":100, "max_depth" : 5}
with open("config.json","w") as f:
    json.dump(config, f, indent=2)

with open("config.json","r") as f:
    loaded = json.load(f)

print(loaded['model'])
# Out:
# RandomForest
