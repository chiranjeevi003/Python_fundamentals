# %% [raw]
# Problem 1 : https://www.hackerrank.com/challenges/itertools-product/problem
# Interview

# %%
from itertools import product

# %%
a = map(int, input().split())
b = map(int, input().split())
c = product(a,b)
for _ in c:
    print(_,end=' ')
# Out:
# 1 2 3
# 4 5 6
# (1, 4) (1, 5) (1, 6) (2, 4) (2, 5) (2, 6) (3, 4) (3, 5) (3, 6)

# %%
# Additional
A = [[1,2,3],[3,4,5]]
print(list(product(*A)))
# Out:
# [(1, 3), (1, 4), (1, 5), (2, 3), (2, 4), (2, 5), (3, 3), (3, 4), (3, 5)]

# %% [raw]
# Problem 2 : https://www.hackerrank.com/challenges/map-and-lambda-expression/problem

# %%
cube = lambda x: x**3 # complete the lambda function 


def fibonacci(n):
    # return a list of fibonacci numbers
    a, b = 0, 1
    f = []
    for _ in range(n):
        f.append(a)
        
        a, b = b, a+b
    return f
            

if __name__ == '__main__':
    n = int(input())
    #print(fibonacci(n))
    print(list(map(cube, fibonacci(n))))
# Out:
# 5
# [0, 1, 1, 8, 27]

# %% [raw]
# Problem 3 : https://www.hackerrank.com/challenges/reduce-function/problem

# %%
from functools import reduce

# %%
reduce(lambda x, y: x + y, [1, 2, 3, 4], -3)
"""
functions : lambda
interbles : list, tuples
intitalizer : -3 
(this is the initial value, on top of this it will apply the function on iterables  )
"""
# Out:
# 10

# %%
from fractions import Fraction
from functools import reduce

def product(fracs):
    t = reduce(lambda x, y: x*y, fracs )# complete this line with a reduce statement
    print(t) #i was curios to know this
    return t.numerator, t.denominator

if __name__ == '__main__':
    fracs = []
    for _ in range(int(input())):
        fracs.append(Fraction(*map(int, input().split())))
    result = product(fracs)
    print(*result) # * will unpack the iterbles.
# Out:
# 3
# 1 2
# 3 4
# 10 6
# 5/8
# 5 8

# %% [raw]
# Problem 4 : https://www.hackerrank.com/challenges/symmetric-difference/problem

# %%
m = int(input())
set_a = set(map(int,input().split()))

n = int(input())
set_b = set(map(int, input().split()))

deff = set_a ^ set_b # a.symetric_difference(b)

for _ in sorted(list(deff)):
    print(_)
# Out:
# 1 2 3 4 5
# 3 4 5 8 0
# 0
# 1
# 2
# 8
