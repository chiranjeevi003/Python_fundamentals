# %% [raw]
# INTERVIEw Problem 1 : https://www.hackerrank.com/challenges/exceptions/problem

# %%
try:
    t = int(input())
except ValueError:
     t = 0
        
for _ in range(t):
    try:
        a, b = input().split()
        print(int(a) // int(b))
        
    except ZeroDivisionError as e:
        print(f'Error Code: {e}')
        
    except ValueError as e:
        print(f'Error Code: {e}')
# Out:
# 3
# 1 0
# Error Code: integer division or modulo by zero
# 2 $
# Error Code: invalid literal for int() with base 10: '$'
# 3 1
# 3

# %% [raw]
# problem 2 : https://www.hackerrank.com/challenges/class-1-dealing-with-complex-numbers/problem
#
#
# Operation,Formula
# Addition: (a+bi)+(c+di)=(a+c)+(b+d)i
# Multiplication: (a+bi)(c+di)=(ac−bd)+(ad+bc)i
# Division: frac({a+bi}{c+di}) = frac({(a+bi)(c-di)}{c^2 + d^2)
# Modulus: $

# %%
import math

class Complex(object):
    def __init__(self, real, imaginary):
        self.real = real
        self.imaginary = imaginary
        
    def __add__(self, no):
        return Complex(self.real + no.real, self.imaginary + no.imaginary )
    def __sub__(self, no):
        return Complex(self.real - no.real, self.imaginary - no.imaginary)
        
    def __mul__(self, no):
        real_part = self.real * no.real - self.imaginary *no.imaginary
        imag_part = self.real * no.imaginary + self.imaginary*no.real
        return Complex(real_part, imag_part)

    def __truediv__(self, no):
        conjugate = Complex(no.real, -no.imaginary)
        denominator = no.real**2 + no.imaginary**2
        numerator = self * conjugate
        return Complex(numerator.real / denominator, numerator.imaginary / denominator)

    def mod(self):
        return Complex(math.sqrt(self.real **2 + self.imaginary**2),0)

    def __str__(self):
        if self.imaginary == 0:
            result = "%.2f+0.00i" % (self.real)
        elif self.real == 0:
            if self.imaginary >= 0:
                result = "0.00+%.2fi" % (self.imaginary)
            else:
                result = "0.00-%.2fi" % (abs(self.imaginary))
        elif self.imaginary > 0:
            result = "%.2f+%.2fi" % (self.real, self.imaginary)
        else:
            result = "%.2f-%.2fi" % (self.real, abs(self.imaginary))
        return result

if __name__ == '__main__':
    c = map(float, input().split())
    d = map(float, input().split())
    x = Complex(*c)
    y = Complex(*d)
    
    print(*map(str, [x+y, x-y, x*y, x/y, x.mod(), y.mod()]), sep='\n')
# Out:
# 2 1
# 5 6
# 7.00+7.00i
# -3.00-5.00i
# 4.00+17.00i
# 0.26-0.11i
# 2.24+0.00i
# 7.81+0.00i
